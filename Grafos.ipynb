# %% [markdown]
# <a href="https://colab.research.google.com/github/ritallopes/pcv-branch-and-bound/blob/main/Grafos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Rodar apenas uma vez para montar o drive e dar permissão
from google.colab import drive
# Mount your Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from itertools import permutations
import time
import os

# %%
def ler_entrada(caminho_arquivo):
    with open(caminho_arquivo, 'r') as file:
        lines = file.readlines()
        num_vertices = int(lines[0].strip())
        custos = {}

        for line in lines[1:]:
            i, j, k, custo = map(int, line.strip().split())
            custos[(i, j, k)] = custo

    return num_vertices, custos

def calcular_custo_tour(tour, custos):
    custo_total = 0
    n = len(tour)
    for i in range(n):
        custo_total += custos.get((tour[i], tour[(i+1) % n], tour[(i+2) % n]), float('inf'))
    return custo_total

def calcular_limite_inferior(tour_parcial, custos, num_vertices):
    # Esta função calcula um limite inferior para um tour parcial
    custo_total = calcular_custo_tour(tour_parcial, custos)
    vertices_restantes = set(range(num_vertices)) - set(tour_parcial)

    if not vertices_restantes:
        return custo_total

    # Adiciona um custo mínimo aproximado para as arestas faltantes
    custo_estimado = 0
    for i in vertices_restantes:
        menor_custo = min(custos.get((tour_parcial[-1], i, j), float('inf')) for j in vertices_restantes)
        custo_estimado += menor_custo

    return custo_total + custo_estimado

def branch_and_bound(num_vertices, custos):
    melhor_tour = None
    melhor_custo = float('inf')
    pilha = [([i], 0) for i in range(num_vertices)]

    while pilha:
        tour_parcial, custo_parcial = pilha.pop()

        if len(tour_parcial) == num_vertices:
            custo_total = calcular_custo_tour(tour_parcial, custos)
            if custo_total < melhor_custo:
                melhor_custo = custo_total
                melhor_tour = tour_parcial
        else:
            limite_inferior = calcular_limite_inferior(tour_parcial, custos, num_vertices)
            if limite_inferior < melhor_custo:
                for i in range(num_vertices):
                    if i not in tour_parcial:
                        novo_tour_parcial = tour_parcial + [i]
                        novo_custo_parcial = calcular_custo_tour(novo_tour_parcial, custos)
                        pilha.append((novo_tour_parcial, novo_custo_parcial))

    return melhor_tour, melhor_custo

# %%
# INTERANDO SOBRE OS ARQUIVOS  NA ORDEM

CAMINHO_PASTA = "/content/drive/My Drive/EDA/Projeto"
CAMINHO_PASTA_ENTRADA = f"{CAMINHO_PASTA}/entrada151617"
CAMINHO_PASTA_SAIDA = f"{CAMINHO_PASTA}/saida5a16"

def gerar_nomes_arquivos():
    nomes_arquivos = []
    for i in range(5, 17):
        for j in range(0, 5):
            nome_arquivo = f"Cópia de FIS{i}-{j}.txt"
            nomes_arquivos.append(nome_arquivo)
    return nomes_arquivos

NOMES_ARQUIVOS = gerar_nomes_arquivos()


def main():
   # Verifica se o diretório de saída existe, caso contrário, cria-o
    os.makedirs(CAMINHO_PASTA_SAIDA, exist_ok=True)
    caminho_arquivo_saida_todos = f"{CAMINHO_PASTA_SAIDA}/all_FIS.txt"
    with open(caminho_arquivo_saida_todos, 'w') as arquivo_saida_all:
        for nome_arquivo in NOMES_ARQUIVOS:
            print(f'Processando arquivo: {nome_arquivo}')

            # Caminho para o arquivo de entrada
            caminho_arquivo_entrada = f"{CAMINHO_PASTA_ENTRADA}/{nome_arquivo}"

            # Caminho para o arquivo de saída
            caminho_arquivo_saida = f"{CAMINHO_PASTA_SAIDA}/{nome_arquivo}"

            # Lendo os dados de entrada
            num_vertices, custos = ler_entrada(caminho_arquivo_entrada)

            # Resolvendo o QTSP usando branch-and-bound
            inicio = time.time()
            melhor_tour, melhor_custo = branch_and_bound(num_vertices, custos)
            fim = time.time()

            # Imprimindo os resultados
            print(f'Melhor tour: {melhor_tour}')
            print(f'Melhor custo: {melhor_custo}')
            print(f'Tempo de execução: {fim - inicio} segundos')
            arquivo_saida_all.write(f'\n\n\nProcessando arquivo: {nome_arquivo}\n')
            arquivo_saida_all.write(f'Melhor tour: {melhor_tour}\n')
            arquivo_saida_all.write(f'Melhor custo: {melhor_custo}\n')
            arquivo_saida_all.write(f'Tempo de execução: {fim - inicio} segundos\n')

            # Escrevendo os resultados em um arquivo de saída
            with open(caminho_arquivo_saida, 'w') as arquivo_saida:
                arquivo_saida.write(f'Processando arquivo: {nome_arquivo}\n')
                arquivo_saida.write(f'Melhor tour: {melhor_tour}\n')
                arquivo_saida.write(f'Melhor custo: {melhor_custo}\n')
                arquivo_saida.write(f'Tempo de execução: {fim - inicio} segundos\n')


if __name__ == "__main__":
    main()
# Out:
# Processando arquivo: Cópia de FIS5-0.txt
# Melhor tour: [4, 3, 0, 2, 1]
# Melhor custo: 18430
# Tempo de execução: 0.0026199817657470703 segundos
# Processando arquivo: Cópia de FIS5-1.txt
# Melhor tour: [4, 2, 3, 1, 0]
# Melhor custo: 22351
# Tempo de execução: 0.001951456069946289 segundos
# Processando arquivo: Cópia de FIS5-2.txt
# Melhor tour: [4, 2, 3, 0, 1]
# Melhor custo: 15356
# Tempo de execução: 0.002687692642211914 segundos
# Processando arquivo: Cópia de FIS5-3.txt
# Melhor tour: [4, 2, 3, 0, 1]
# Melhor custo: 21245
# Tempo de execução: 0.001699209213256836 segundos
# Processando arquivo: Cópia de FIS5-4.txt
# Melhor tour: [4, 3, 2, 0, 1]
# Melhor custo: 19418
# Tempo de execução: 0.001745462417602539 segundos
# Processando arquivo: Cópia de FIS6-0.txt
# Melhor tour: [5, 3, 4, 0, 1, 2]
# Melhor custo: 15576
# Tempo de execução: 0.005484342575073242 segundos
# Processando arquivo: Cópia de FIS6-1.txt
# Melhor tour: [5, 4, 2, 3, 1, 0]
# Melhor custo: 19436
# Tempo de execução: 0.013214826583862305 segundos
# Processando arquivo: Cópia de FIS6-2.txt
# Melhor tour: [5, 4, 1, 0, 2, 3]
# Melhor custo: 23991
# Tempo de execução: 0.017319440841674805 segundos
# Processando arquivo: Cópia de FIS6-3.txt
# Melhor tour: [5, 0, 2, 4, 1, 3]
# Melhor custo: 13819
# Tempo de execução: 0.009078502655029297 segundos
# Processando arquivo: Cópia de FIS6-4.txt
# Melhor tour: [5, 3, 1, 2, 4, 0]
# Melhor custo: 16139
# Tempo de execução: 0.013263702392578125 segundos
# Processando arquivo: Cópia de FIS7-0.txt
# Melhor tour: [6, 3, 1, 4, 2, 5, 0]
# Melhor custo: 16355
# Tempo de execução: 0.0557551383972168 segundos
# Processando arquivo: Cópia de FIS7-1.txt
# Melhor tour: [5, 4, 1, 6, 2, 0, 3]
# Melhor custo: 20251
# Tempo de execução: 0.0642538070678711 segundos
# Processando arquivo: Cópia de FIS7-2.txt
# Melhor tour: [0, 5, 6, 4, 3, 1, 2]
# Melhor custo: 8243
# Tempo de execução: 0.013510704040527344 segundos
# Processando arquivo: Cópia de FIS7-3.txt
# Melhor tour: [6, 4, 5, 2, 0, 3, 1]
# Melhor custo: 19494
# Tempo de execução: 0.054732561111450195 segundos
# Processando arquivo: Cópia de FIS7-4.txt
# Melhor tour: [6, 4, 3, 1, 0, 5, 2]
# Melhor custo: 24395
# Tempo de execução: 0.0474698543548584 segundos
# Processando arquivo: Cópia de FIS8-0.txt
# Melhor tour: [6, 4, 7, 0, 3, 5, 2, 1]
# Melhor custo: 19668
# Tempo de execução: 0.12161040306091309 segundos
# Processando arquivo: Cópia de FIS8-1.txt
# Melhor tour: [7, 1, 2, 4, 5, 6, 3, 0]
# Melhor custo: 17845
# Tempo de execução: 0.10374736785888672 segundos
# Processando arquivo: Cópia de FIS8-2.txt
# Melhor tour: [7, 2, 4, 0, 3, 1, 6, 5]
# Melhor custo: 12652
# Tempo de execução: 0.02337813377380371 segundos
# Processando arquivo: Cópia de FIS8-3.txt
# Melhor tour: [4, 3, 0, 6, 7, 5, 2, 1]
# Melhor custo: 15018
# Tempo de execução: 0.05341339111328125 segundos
# Processando arquivo: Cópia de FIS8-4.txt
# Melhor tour: [7, 3, 1, 2, 4, 6, 5, 0]
# Melhor custo: 19030
# Tempo de execução: 0.16018438339233398 segundos
# Processando arquivo: Cópia de FIS9-0.txt
# Melhor tour: [7, 2, 3, 1, 6, 5, 4, 0, 8]
# Melhor custo: 19211
# Tempo de execução: 0.28427696228027344 segundos
# Processando arquivo: Cópia de FIS9-1.txt
# Melhor tour: [8, 7, 1, 6, 0, 3, 2, 5, 4]
# Melhor custo: 25376
# Tempo de execução: 1.0895509719848633 segundos
# Processando arquivo: Cópia de FIS9-2.txt
# Melhor tour: [8, 6, 4, 3, 2, 0, 7, 5, 1]
# Melhor custo: 29033
# Tempo de execução: 1.5206348896026611 segundos
# Processando arquivo: Cópia de FIS9-3.txt
# Melhor tour: [8, 2, 7, 0, 1, 3, 5, 6, 4]
# Melhor custo: 17895
# Tempo de execução: 0.4199953079223633 segundos
# Processando arquivo: Cópia de FIS9-4.txt
# Melhor tour: [7, 2, 6, 3, 8, 5, 0, 1, 4]
# Melhor custo: 18675
# Tempo de execução: 0.3219425678253174 segundos
# Processando arquivo: Cópia de FIS10-0.txt
# Melhor tour: [9, 5, 4, 2, 8, 6, 7, 1, 0, 3]
# Melhor custo: 17971
# Tempo de execução: 0.6386728286743164 segundos
# Processando arquivo: Cópia de FIS10-1.txt
# Melhor tour: [9, 6, 8, 3, 0, 4, 2, 5, 7, 1]
# Melhor custo: 19192
# Tempo de execução: 1.0679423809051514 segundos
# Processando arquivo: Cópia de FIS10-2.txt
# Melhor tour: [8, 9, 7, 5, 1, 0, 3, 2, 6, 4]
# Melhor custo: 22022
# Tempo de execução: 2.7992382049560547 segundos
# Processando arquivo: Cópia de FIS10-3.txt
# Melhor tour: [9, 5, 1, 7, 6, 8, 0, 2, 4, 3]
# Melhor custo: 14404
# Tempo de execução: 0.4037773609161377 segundos
# Processando arquivo: Cópia de FIS10-4.txt
# Melhor tour: [9, 8, 3, 7, 0, 4, 6, 5, 2, 1]
# Melhor custo: 15170
# Tempo de execução: 1.3261990547180176 segundos
# Processando arquivo: Cópia de FIS11-0.txt
# Melhor tour: [9, 1, 6, 8, 10, 7, 3, 4, 0, 2, 5]
# Melhor custo: 19179
# Tempo de execução: 2.8830490112304688 segundos
# Processando arquivo: Cópia de FIS11-1.txt
# Melhor tour: [10, 8, 4, 5, 1, 2, 0, 7, 3, 9, 6]
# Melhor custo: 22379
# Tempo de execução: 4.4308977127075195 segundos
# Processando arquivo: Cópia de FIS11-2.txt
# Melhor tour: [10, 0, 9, 6, 4, 8, 7, 3, 1, 5, 2]
# Melhor custo: 23672
# Tempo de execução: 18.530866622924805 segundos
# Processando arquivo: Cópia de FIS11-3.txt
# Melhor tour: [6, 0, 10, 3, 2, 5, 8, 7, 9, 4, 1]
# Melhor custo: 23243
# Tempo de execução: 9.983665704727173 segundos
# Processando arquivo: Cópia de FIS11-4.txt
# Melhor tour: [10, 8, 9, 6, 4, 0, 1, 2, 3, 5, 7]
# Melhor custo: 20913
# Tempo de execução: 8.154107570648193 segundos
# Processando arquivo: Cópia de FIS12-0.txt
# Melhor tour: [10, 3, 2, 0, 4, 1, 9, 11, 6, 5, 7, 8]
# Melhor custo: 23875
# Tempo de execução: 42.572202920913696 segundos
# Processando arquivo: Cópia de FIS12-1.txt
# Melhor tour: [11, 6, 10, 4, 1, 0, 3, 2, 7, 8, 5, 9]
# Melhor custo: 25024
# Tempo de execução: 47.31995630264282 segundos
# Processando arquivo: Cópia de FIS12-2.txt
# Melhor tour: [11, 1, 9, 0, 10, 7, 8, 2, 3, 5, 4, 6]
# Melhor custo: 28677
# Tempo de execução: 87.62306380271912 segundos
# Processando arquivo: Cópia de FIS12-3.txt
# Melhor tour: [6, 0, 10, 9, 5, 8, 3, 1, 7, 4, 11, 2]
# Melhor custo: 19391
# Tempo de execução: 16.007454872131348 segundos
# Processando arquivo: Cópia de FIS12-4.txt
# Melhor tour: [9, 3, 1, 7, 10, 6, 8, 2, 0, 11, 4, 5]
# Melhor custo: 24669
# Tempo de execução: 48.95887899398804 segundos
# Processando arquivo: Cópia de FIS13-0.txt
# Melhor tour: [10, 4, 12, 11, 7, 5, 6, 1, 9, 2, 8, 0, 3]
# Melhor custo: 21813
# Tempo de execução: 64.54034805297852 segundos
# Processando arquivo: Cópia de FIS13-1.txt
# Melhor tour: [12, 5, 1, 7, 10, 9, 2, 4, 11, 8, 6, 0, 3]
# Melhor custo: 27120
# Tempo de execução: 273.62911796569824 segundos
# Processando arquivo: Cópia de FIS13-2.txt
# Melhor tour: [3, 4, 8, 9, 10, 6, 0, 1, 2, 7, 5, 11, 12]
# Melhor custo: 22463
# Tempo de execução: 71.6813292503357 segundos
# Processando arquivo: Cópia de FIS13-3.txt
# Melhor tour: [7, 2, 3, 6, 12, 1, 4, 10, 0, 8, 5, 9, 11]
# Melhor custo: 16817
# Tempo de execução: 24.96774435043335 segundos
# Processando arquivo: Cópia de FIS13-4.txt
# Melhor tour: [11, 12, 7, 10, 4, 2, 6, 3, 0, 1, 8, 5, 9]
# Melhor custo: 18826
# Tempo de execução: 31.02118492126465 segundos
# Processando arquivo: Cópia de FIS14-0.txt
# Melhor tour: [6, 4, 0, 11, 13, 10, 7, 3, 1, 2, 12, 9, 8, 5]
# Melhor custo: 24042
# Tempo de execução: 716.9869933128357 segundos
# Processando arquivo: Cópia de FIS14-1.txt
# Melhor tour: [11, 2, 5, 1, 3, 9, 13, 4, 0, 12, 8, 6, 10, 7]
# Melhor custo: 31600
# Tempo de execução: 2566.2476518154144 segundos
# Processando arquivo: Cópia de FIS14-2.txt
# Melhor tour: [7, 11, 8, 10, 5, 9, 3, 1, 0, 4, 12, 13, 2, 6]
# Melhor custo: 25265
# Tempo de execução: 767.6708920001984 segundos
# Processando arquivo: Cópia de FIS14-3.txt
# Melhor tour: [13, 10, 12, 9, 3, 7, 0, 5, 8, 6, 2, 1, 11, 4]
# Melhor custo: 22374
# Tempo de execução: 217.30350852012634 segundos
# Processando arquivo: Cópia de FIS14-4.txt
# Melhor tour: [13, 1, 5, 0, 8, 12, 7, 9, 10, 11, 6, 4, 3, 2]
# Melhor custo: 27044
# Tempo de execução: 908.6354336738586 segundos
# Processando arquivo: Cópia de FIS15-0.txt
# Melhor tour: [14, 0, 10, 3, 12, 6, 5, 1, 9, 11, 13, 2, 7, 4, 8]
# Melhor custo: 22304
# Tempo de execução: 1751.0891227722168 segundos
# Processando arquivo: Cópia de FIS15-1.txt
# Melhor tour: [5, 2, 3, 0, 6, 1, 12, 11, 13, 14, 4, 7, 10, 8, 9]
# Melhor custo: 26234
# Tempo de execução: 1596.7993874549866 segundos
# Processando arquivo: Cópia de FIS15-2.txt
# Melhor tour: [12, 4, 11, 2, 6, 1, 10, 3, 14, 7, 9, 5, 0, 8, 13]
# Melhor custo: 23143
# Tempo de execução: 680.0234451293945 segundos
# Processando arquivo: Cópia de FIS15-3.txt
# Melhor tour: [9, 13, 10, 7, 8, 5, 4, 12, 6, 2, 14, 1, 11, 0, 3]
# Melhor custo: 25303
# Tempo de execução: 2914.8735654354095 segundos
# Processando arquivo: Cópia de FIS15-4.txt
# Melhor tour: [11, 14, 8, 10, 7, 4, 6, 5, 9, 2, 0, 3, 13, 1, 12]
# Melhor custo: 23962
# Tempo de execução: 1272.2944314479828 segundos
# Processando arquivo: Cópia de FIS16-0.txt
# Melhor tour: [8, 13, 0, 14, 10, 15, 5, 1, 9, 4, 7, 11, 12, 3, 6, 2]
# Melhor custo: 22406
# Tempo de execução: 2475.8333792686462 segundos
# Processando arquivo: Cópia de FIS16-1.txt
# Melhor tour: [13, 1, 2, 4, 15, 7, 9, 0, 3, 6, 5, 8, 14, 10, 12, 11]
# Melhor custo: 21036
# Tempo de execução: 1141.4148483276367 segundos
# Processando arquivo: Cópia de FIS16-2.txt

# %%
def ler_entrada(caminho_arquivo):
    with open(caminho_arquivo, 'r') as file:
        lines = file.readlines()
        num_vertices = int(lines[0].strip())
        custos = {}

        for line in lines[1:]:
            i, j, k, custo = map(int, line.strip().split())
            custos[(i, j, k)] = custo

    return num_vertices, custos

def calcular_custo_tour(tour, custos):
    custo_total = 0
    n = len(tour)
    for i in range(n):
        custo_total += custos.get((tour[i], tour[(i+1) % n], tour[(i+2) % n]), float('inf'))
    return custo_total

def calcular_limite_inferior(tour_parcial, custos, num_vertices):
    # Esta função calcula um limite inferior para um tour parcial
    custo_total = calcular_custo_tour(tour_parcial, custos)
    vertices_restantes = set(range(num_vertices)) - set(tour_parcial)

    if not vertices_restantes:
        return custo_total

    # Adiciona um custo mínimo aproximado para as arestas faltantes
    custo_estimado = 0
    for i in vertices_restantes:
        menor_custo = min(custos.get((tour_parcial[-1], i, j), float('inf')) for j in vertices_restantes)
        custo_estimado += menor_custo

    return custo_total + custo_estimado

def branch_and_bound(num_vertices, custos):
    melhor_tour = None
    melhor_custo = float('inf')
    pilha = [([i], 0) for i in range(num_vertices)]

    while pilha:
        tour_parcial, custo_parcial = pilha.pop()

        if len(tour_parcial) == num_vertices:
            custo_total = calcular_custo_tour(tour_parcial, custos)
            if custo_total < melhor_custo:
                melhor_custo = custo_total
                melhor_tour = tour_parcial
        else:
            limite_inferior = calcular_limite_inferior(tour_parcial, custos, num_vertices)
            if limite_inferior < melhor_custo:
                for i in range(num_vertices):
                    if i not in tour_parcial:
                        novo_tour_parcial = tour_parcial + [i]
                        novo_custo_parcial = calcular_custo_tour(novo_tour_parcial, custos)
                        pilha.append((novo_tour_parcial, novo_custo_parcial))

    return melhor_tour, melhor_custo

# %%
def ler_entrada(caminho_arquivo):
    with open(caminho_arquivo, 'r') as file:
        lines = file.readlines()
        num_vertices = int(lines[0].strip())
        custos = {}

        for line in lines[1:]:
            i, j, k, custo = map(int, line.strip().split())
            custos[(i, j, k)] = custo

    return num_vertices, custos

def calcular_custo_tour(tour, custos):
    custo_total = 0
    n = len(tour)
    for i in range(n):
        custo_total += custos.get((tour[i], tour[(i+1) % n], tour[(i+2) % n]), float('inf'))
    return custo_total

def calcular_limite_inferior(tour_parcial, custos, num_vertices):
    # Esta função calcula um limite inferior para um tour parcial
    custo_total = calcular_custo_tour(tour_parcial, custos)
    vertices_restantes = set(range(num_vertices)) - set(tour_parcial)

    if not vertices_restantes:
        return custo_total

    # Adiciona um custo mínimo aproximado para as arestas faltantes
    custo_estimado = 0
    for i in vertices_restantes:
        menor_custo = min(custos.get((tour_parcial[-1], i, j), float('inf')) for j in vertices_restantes)
        custo_estimado += menor_custo

    return custo_total + custo_estimado

def branch_and_bound(num_vertices, custos):
    melhor_tour = None
    melhor_custo = float('inf')
    pilha = [([i], 0) for i in range(num_vertices)]

    while pilha:
        tour_parcial, custo_parcial = pilha.pop()

        if len(tour_parcial) == num_vertices:
            custo_total = calcular_custo_tour(tour_parcial, custos)
            if custo_total < melhor_custo:
                melhor_custo = custo_total
                melhor_tour = tour_parcial
        else:
            limite_inferior = calcular_limite_inferior(tour_parcial, custos, num_vertices)
            if limite_inferior < melhor_custo:
                for i in range(num_vertices):
                    if i not in tour_parcial:
                        novo_tour_parcial = tour_parcial + [i]
                        novo_custo_parcial = calcular_custo_tour(novo_tour_parcial, custos)
                        pilha.append((novo_tour_parcial, novo_custo_parcial))

    return melhor_tour, melhor_custo

# %%
def ler_entrada(caminho_arquivo):
    with open(caminho_arquivo, 'r') as file:
        lines = file.readlines()
        num_vertices = int(lines[0].strip())
        custos = {}

        for line in lines[1:]:
            i, j, k, custo = map(int, line.strip().split())
            custos[(i, j, k)] = custo

    return num_vertices, custos

def calcular_custo_tour(tour, custos):
    custo_total = 0
    n = len(tour)
    for i in range(n):
        custo_total += custos.get((tour[i], tour[(i+1) % n], tour[(i+2) % n]), float('inf'))
    return custo_total

def calcular_limite_inferior(tour_parcial, custos, num_vertices):
    # Esta função calcula um limite inferior para um tour parcial
    custo_total = calcular_custo_tour(tour_parcial, custos)
    vertices_restantes = set(range(num_vertices)) - set(tour_parcial)

    if not vertices_restantes:
        return custo_total

    # Adiciona um custo mínimo aproximado para as arestas faltantes
    custo_estimado = 0
    for i in vertices_restantes:
        menor_custo = min(custos.get((tour_parcial[-1], i, j), float('inf')) for j in vertices_restantes)
        custo_estimado += menor_custo

    return custo_total + custo_estimado

def branch_and_bound(num_vertices, custos):
    melhor_tour = None
    melhor_custo = float('inf')
    pilha = [([i], 0) for i in range(num_vertices)]

    while pilha:
        tour_parcial, custo_parcial = pilha.pop()

        if len(tour_parcial) == num_vertices:
            custo_total = calcular_custo_tour(tour_parcial, custos)
            if custo_total < melhor_custo:
                melhor_custo = custo_total
                melhor_tour = tour_parcial
        else:
            limite_inferior = calcular_limite_inferior(tour_parcial, custos, num_vertices)
            if limite_inferior < melhor_custo:
                for i in range(num_vertices):
                    if i not in tour_parcial:
                        novo_tour_parcial = tour_parcial + [i]
                        novo_custo_parcial = calcular_custo_tour(novo_tour_parcial, custos)
                        pilha.append((novo_tour_parcial, novo_custo_parcial))

    return melhor_tour, melhor_custo

# %%
def ler_entrada(caminho_arquivo):
    with open(caminho_arquivo, 'r') as file:
        lines = file.readlines()
        num_vertices = int(lines[0].strip())
        custos = {}

        for line in lines[1:]:
            i, j, k, custo = map(int, line.strip().split())
            custos[(i, j, k)] = custo

    return num_vertices, custos

def calcular_custo_tour(tour, custos):
    custo_total = 0
    n = len(tour)
    for i in range(n):
        custo_total += custos.get((tour[i], tour[(i+1) % n], tour[(i+2) % n]), float('inf'))
    return custo_total

def calcular_limite_inferior(tour_parcial, custos, num_vertices):
    # Esta função calcula um limite inferior para um tour parcial
    custo_total = calcular_custo_tour(tour_parcial, custos)
    vertices_restantes = set(range(num_vertices)) - set(tour_parcial)

    if not vertices_restantes:
        return custo_total

    # Adiciona um custo mínimo aproximado para as arestas faltantes
    custo_estimado = 0
    for i in vertices_restantes:
        menor_custo = min(custos.get((tour_parcial[-1], i, j), float('inf')) for j in vertices_restantes)
        custo_estimado += menor_custo

    return custo_total + custo_estimado

def branch_and_bound(num_vertices, custos):
    melhor_tour = None
    melhor_custo = float('inf')
    pilha = [([i], 0) for i in range(num_vertices)]

    while pilha:
        tour_parcial, custo_parcial = pilha.pop()

        if len(tour_parcial) == num_vertices:
            custo_total = calcular_custo_tour(tour_parcial, custos)
            if custo_total < melhor_custo:
                melhor_custo = custo_total
                melhor_tour = tour_parcial
        else:
            limite_inferior = calcular_limite_inferior(tour_parcial, custos, num_vertices)
            if limite_inferior < melhor_custo:
                for i in range(num_vertices):
                    if i not in tour_parcial:
                        novo_tour_parcial = tour_parcial + [i]
                        novo_custo_parcial = calcular_custo_tour(novo_tour_parcial, custos)
                        pilha.append((novo_tour_parcial, novo_custo_parcial))

    return melhor_tour, melhor_custo

# %%
def ler_entrada(caminho_arquivo):
    with open(caminho_arquivo, 'r') as file:
        lines = file.readlines()
        num_vertices = int(lines[0].strip())
        custos = {}

        for line in lines[1:]:
            i, j, k, custo = map(int, line.strip().split())
            custos[(i, j, k)] = custo

    return num_vertices, custos

def calcular_custo_tour(tour, custos):
    custo_total = 0
    n = len(tour)
    for i in range(n):
        custo_total += custos.get((tour[i], tour[(i+1) % n], tour[(i+2) % n]), float('inf'))
    return custo_total

def calcular_limite_inferior(tour_parcial, custos, num_vertices):
    # Esta função calcula um limite inferior para um tour parcial
    custo_total = calcular_custo_tour(tour_parcial, custos)
    vertices_restantes = set(range(num_vertices)) - set(tour_parcial)

    if not vertices_restantes:
        return custo_total

    # Adiciona um custo mínimo aproximado para as arestas faltantes
    custo_estimado = 0
    for i in vertices_restantes:
        menor_custo = min(custos.get((tour_parcial[-1], i, j), float('inf')) for j in vertices_restantes)
        custo_estimado += menor_custo

    return custo_total + custo_estimado

def branch_and_bound(num_vertices, custos):
    melhor_tour = None
    melhor_custo = float('inf')
    pilha = [([i], 0) for i in range(num_vertices)]

    while pilha:
        tour_parcial, custo_parcial = pilha.pop()

        if len(tour_parcial) == num_vertices:
            custo_total = calcular_custo_tour(tour_parcial, custos)
            if custo_total < melhor_custo:
                melhor_custo = custo_total
                melhor_tour = tour_parcial
        else:
            limite_inferior = calcular_limite_inferior(tour_parcial, custos, num_vertices)
            if limite_inferior < melhor_custo:
                for i in range(num_vertices):
                    if i not in tour_parcial:
                        novo_tour_parcial = tour_parcial + [i]
                        novo_custo_parcial = calcular_custo_tour(novo_tour_parcial, custos)
                        pilha.append((novo_tour_parcial, novo_custo_parcial))

    return melhor_tour, melhor_custo

# %%
def ler_entrada(caminho_arquivo):
    with open(caminho_arquivo, 'r') as file:
        lines = file.readlines()
        num_vertices = int(lines[0].strip())
        custos = {}

        for line in lines[1:]:
            i, j, k, custo = map(int, line.strip().split())
            custos[(i, j, k)] = custo

    return num_vertices, custos

def calcular_custo_tour(tour, custos):
    custo_total = 0
    n = len(tour)
    for i in range(n):
        custo_total += custos.get((tour[i], tour[(i+1) % n], tour[(i+2) % n]), float('inf'))
    return custo_total

def calcular_limite_inferior(tour_parcial, custos, num_vertices):
    # Esta função calcula um limite inferior para um tour parcial
    custo_total = calcular_custo_tour(tour_parcial, custos)
    vertices_restantes = set(range(num_vertices)) - set(tour_parcial)

    if not vertices_restantes:
        return custo_total

    # Adiciona um custo mínimo aproximado para as arestas faltantes
    custo_estimado = 0
    for i in vertices_restantes:
        menor_custo = min(custos.get((tour_parcial[-1], i, j), float('inf')) for j in vertices_restantes)
        custo_estimado += menor_custo

    return custo_total + custo_estimado

def branch_and_bound(num_vertices, custos):
    melhor_tour = None
    melhor_custo = float('inf')
    pilha = [([i], 0) for i in range(num_vertices)]

    while pilha:
        tour_parcial, custo_parcial = pilha.pop()

        if len(tour_parcial) == num_vertices:
            custo_total = calcular_custo_tour(tour_parcial, custos)
            if custo_total < melhor_custo:
                melhor_custo = custo_total
                melhor_tour = tour_parcial
        else:
            limite_inferior = calcular_limite_inferior(tour_parcial, custos, num_vertices)
            if limite_inferior < melhor_custo:
                for i in range(num_vertices):
                    if i not in tour_parcial:
                        novo_tour_parcial = tour_parcial + [i]
                        novo_custo_parcial = calcular_custo_tour(novo_tour_parcial, custos)
                        pilha.append((novo_tour_parcial, novo_custo_parcial))

    return melhor_tour, melhor_custo

# %%
def ler_entrada(caminho_arquivo):
    with open(caminho_arquivo, 'r') as file:
        lines = file.readlines()
        num_vertices = int(lines[0].strip())
        custos = {}

        for line in lines[1:]:
            i, j, k, custo = map(int, line.strip().split())
            custos[(i, j, k)] = custo

    return num_vertices, custos

def calcular_custo_tour(tour, custos):
    custo_total = 0
    n = len(tour)
    for i in range(n):
        custo_total += custos.get((tour[i], tour[(i+1) % n], tour[(i+2) % n]), float('inf'))
    return custo_total

def calcular_limite_inferior(tour_parcial, custos, num_vertices):
    # Esta função calcula um limite inferior para um tour parcial
    custo_total = calcular_custo_tour(tour_parcial, custos)
    vertices_restantes = set(range(num_vertices)) - set(tour_parcial)

    if not vertices_restantes:
        return custo_total

    # Adiciona um custo mínimo aproximado para as arestas faltantes
    custo_estimado = 0
    for i in vertices_restantes:
        menor_custo = min(custos.get((tour_parcial[-1], i, j), float('inf')) for j in vertices_restantes)
        custo_estimado += menor_custo

    return custo_total + custo_estimado

def branch_and_bound(num_vertices, custos):
    melhor_tour = None
    melhor_custo = float('inf')
    pilha = [([i], 0) for i in range(num_vertices)]

    while pilha:
        tour_parcial, custo_parcial = pilha.pop()

        if len(tour_parcial) == num_vertices:
            custo_total = calcular_custo_tour(tour_parcial, custos)
            if custo_total < melhor_custo:
                melhor_custo = custo_total
                melhor_tour = tour_parcial
        else:
            limite_inferior = calcular_limite_inferior(tour_parcial, custos, num_vertices)
            if limite_inferior < melhor_custo:
                for i in range(num_vertices):
                    if i not in tour_parcial:
                        novo_tour_parcial = tour_parcial + [i]
                        novo_custo_parcial = calcular_custo_tour(novo_tour_parcial, custos)
                        pilha.append((novo_tour_parcial, novo_custo_parcial))

    return melhor_tour, melhor_custo

# %%
def ler_entrada(caminho_arquivo):
    with open(caminho_arquivo, 'r') as file:
        lines = file.readlines()
        num_vertices = int(lines[0].strip())
        custos = {}

        for line in lines[1:]:
            i, j, k, custo = map(int, line.strip().split())
            custos[(i, j, k)] = custo

    return num_vertices, custos

def calcular_custo_tour(tour, custos):
    custo_total = 0
    n = len(tour)
    for i in range(n):
        custo_total += custos.get((tour[i], tour[(i+1) % n], tour[(i+2) % n]), float('inf'))
    return custo_total

def calcular_limite_inferior(tour_parcial, custos, num_vertices):
    # Esta função calcula um limite inferior para um tour parcial
    custo_total = calcular_custo_tour(tour_parcial, custos)
    vertices_restantes = set(range(num_vertices)) - set(tour_parcial)

    if not vertices_restantes:
        return custo_total

    # Adiciona um custo mínimo aproximado para as arestas faltantes
    custo_estimado = 0
    for i in vertices_restantes:
        menor_custo = min(custos.get((tour_parcial[-1], i, j), float('inf')) for j in vertices_restantes)
        custo_estimado += menor_custo

    return custo_total + custo_estimado

def branch_and_bound(num_vertices, custos):
    melhor_tour = None
    melhor_custo = float('inf')
    pilha = [([i], 0) for i in range(num_vertices)]

    while pilha:
        tour_parcial, custo_parcial = pilha.pop()

        if len(tour_parcial) == num_vertices:
            custo_total = calcular_custo_tour(tour_parcial, custos)
            if custo_total < melhor_custo:
                melhor_custo = custo_total
                melhor_tour = tour_parcial
        else:
            limite_inferior = calcular_limite_inferior(tour_parcial, custos, num_vertices)
            if limite_inferior < melhor_custo:
                for i in range(num_vertices):
                    if i not in tour_parcial:
                        novo_tour_parcial = tour_parcial + [i]
                        novo_custo_parcial = calcular_custo_tour(novo_tour_parcial, custos)
                        pilha.append((novo_tour_parcial, novo_custo_parcial))

    return melhor_tour, melhor_custo

# %%
def ler_entrada(caminho_arquivo):
    with open(caminho_arquivo, 'r') as file:
        lines = file.readlines()
        num_vertices = int(lines[0].strip())
        custos = {}

        for line in lines[1:]:
            i, j, k, custo = map(int, line.strip().split())
            custos[(i, j, k)] = custo

    return num_vertices, custos

def calcular_custo_tour(tour, custos):
    custo_total = 0
    n = len(tour)
    for i in range(n):
        custo_total += custos.get((tour[i], tour[(i+1) % n], tour[(i+2) % n]), float('inf'))
    return custo_total

def calcular_limite_inferior(tour_parcial, custos, num_vertices):
    # Esta função calcula um limite inferior para um tour parcial
    custo_total = calcular_custo_tour(tour_parcial, custos)
    vertices_restantes = set(range(num_vertices)) - set(tour_parcial)

    if not vertices_restantes:
        return custo_total

    # Adiciona um custo mínimo aproximado para as arestas faltantes
    custo_estimado = 0
    for i in vertices_restantes:
        menor_custo = min(custos.get((tour_parcial[-1], i, j), float('inf')) for j in vertices_restantes)
        custo_estimado += menor_custo

    return custo_total + custo_estimado

def branch_and_bound(num_vertices, custos):
    melhor_tour = None
    melhor_custo = float('inf')
    pilha = [([i], 0) for i in range(num_vertices)]

    while pilha:
        tour_parcial, custo_parcial = pilha.pop()

        if len(tour_parcial) == num_vertices:
            custo_total = calcular_custo_tour(tour_parcial, custos)
            if custo_total < melhor_custo:
                melhor_custo = custo_total
                melhor_tour = tour_parcial
        else:
            limite_inferior = calcular_limite_inferior(tour_parcial, custos, num_vertices)
            if limite_inferior < melhor_custo:
                for i in range(num_vertices):
                    if i not in tour_parcial:
                        novo_tour_parcial = tour_parcial + [i]
                        novo_custo_parcial = calcular_custo_tour(novo_tour_parcial, custos)
                        pilha.append((novo_tour_parcial, novo_custo_parcial))

    return melhor_tour, melhor_custo

# %%
def ler_entrada(caminho_arquivo):
    with open(caminho_arquivo, 'r') as file:
        lines = file.readlines()
        num_vertices = int(lines[0].strip())
        custos = {}

        for line in lines[1:]:
            i, j, k, custo = map(int, line.strip().split())
            custos[(i, j, k)] = custo

    return num_vertices, custos

def calcular_custo_tour(tour, custos):
    custo_total = 0
    n = len(tour)
    for i in range(n):
        custo_total += custos.get((tour[i], tour[(i+1) % n], tour[(i+2) % n]), float('inf'))
    return custo_total

def calcular_limite_inferior(tour_parcial, custos, num_vertices):
    # Esta função calcula um limite inferior para um tour parcial
    custo_total = calcular_custo_tour(tour_parcial, custos)
    vertices_restantes = set(range(num_vertices)) - set(tour_parcial)

    if not vertices_restantes:
        return custo_total

    # Adiciona um custo mínimo aproximado para as arestas faltantes
    custo_estimado = 0
    for i in vertices_restantes:
        menor_custo = min(custos.get((tour_parcial[-1], i, j), float('inf')) for j in vertices_restantes)
        custo_estimado += menor_custo

    return custo_total + custo_estimado

def branch_and_bound(num_vertices, custos):
    melhor_tour = None
    melhor_custo = float('inf')
    pilha = [([i], 0) for i in range(num_vertices)]

    while pilha:
        tour_parcial, custo_parcial = pilha.pop()

        if len(tour_parcial) == num_vertices:
            custo_total = calcular_custo_tour(tour_parcial, custos)
            if custo_total < melhor_custo:
                melhor_custo = custo_total
                melhor_tour = tour_parcial
        else:
            limite_inferior = calcular_limite_inferior(tour_parcial, custos, num_vertices)
            if limite_inferior < melhor_custo:
                for i in range(num_vertices):
                    if i not in tour_parcial:
                        novo_tour_parcial = tour_parcial + [i]
                        novo_custo_parcial = calcular_custo_tour(novo_tour_parcial, custos)
                        pilha.append((novo_tour_parcial, novo_custo_parcial))

    return melhor_tour, melhor_custo

# %%
def ler_entrada(caminho_arquivo):
    with open(caminho_arquivo, 'r') as file:
        lines = file.readlines()
        num_vertices = int(lines[0].strip())
        custos = {}

        for line in lines[1:]:
            i, j, k, custo = map(int, line.strip().split())
            custos[(i, j, k)] = custo

    return num_vertices, custos

def calcular_custo_tour(tour, custos):
    custo_total = 0
    n = len(tour)
    for i in range(n):
        custo_total += custos.get((tour[i], tour[(i+1) % n], tour[(i+2) % n]), float('inf'))
    return custo_total

def calcular_limite_inferior(tour_parcial, custos, num_vertices):
    # Esta função calcula um limite inferior para um tour parcial
    custo_total = calcular_custo_tour(tour_parcial, custos)
    vertices_restantes = set(range(num_vertices)) - set(tour_parcial)

    if not vertices_restantes:
        return custo_total

    # Adiciona um custo mínimo aproximado para as arestas faltantes
    custo_estimado = 0
    for i in vertices_restantes:
        menor_custo = min(custos.get((tour_parcial[-1], i, j), float('inf')) for j in vertices_restantes)
        custo_estimado += menor_custo

    return custo_total + custo_estimado

def branch_and_bound(num_vertices, custos):
    melhor_tour = None
    melhor_custo = float('inf')
    pilha = [([i], 0) for i in range(num_vertices)]

    while pilha:
        tour_parcial, custo_parcial = pilha.pop()

        if len(tour_parcial) == num_vertices:
            custo_total = calcular_custo_tour(tour_parcial, custos)
            if custo_total < melhor_custo:
                melhor_custo = custo_total
                melhor_tour = tour_parcial
        else:
            limite_inferior = calcular_limite_inferior(tour_parcial, custos, num_vertices)
            if limite_inferior < melhor_custo:
                for i in range(num_vertices):
                    if i not in tour_parcial:
                        novo_tour_parcial = tour_parcial + [i]
                        novo_custo_parcial = calcular_custo_tour(novo_tour_parcial, custos)
                        pilha.append((novo_tour_parcial, novo_custo_parcial))

    return melhor_tour, melhor_custo

# %%
def ler_entrada(caminho_arquivo):
    with open(caminho_arquivo, 'r') as file:
        lines = file.readlines()
        num_vertices = int(lines[0].strip())
        custos = {}

        for line in lines[1:]:
            i, j, k, custo = map(int, line.strip().split())
            custos[(i, j, k)] = custo

    return num_vertices, custos

def calcular_custo_tour(tour, custos):
    custo_total = 0
    n = len(tour)
    for i in range(n):
        custo_total += custos.get((tour[i], tour[(i+1) % n], tour[(i+2) % n]), float('inf'))
    return custo_total

def calcular_limite_inferior(tour_parcial, custos, num_vertices):
    # Esta função calcula um limite inferior para um tour parcial
    custo_total = calcular_custo_tour(tour_parcial, custos)
    vertices_restantes = set(range(num_vertices)) - set(tour_parcial)

    if not vertices_restantes:
        return custo_total

    # Adiciona um custo mínimo aproximado para as arestas faltantes
    custo_estimado = 0
    for i in vertices_restantes:
        menor_custo = min(custos.get((tour_parcial[-1], i, j), float('inf')) for j in vertices_restantes)
        custo_estimado += menor_custo

    return custo_total + custo_estimado

def branch_and_bound(num_vertices, custos):
    melhor_tour = None
    melhor_custo = float('inf')
    pilha = [([i], 0) for i in range(num_vertices)]

    while pilha:
        tour_parcial, custo_parcial = pilha.pop()

        if len(tour_parcial) == num_vertices:
            custo_total = calcular_custo_tour(tour_parcial, custos)
            if custo_total < melhor_custo:
                melhor_custo = custo_total
                melhor_tour = tour_parcial
        else:
            limite_inferior = calcular_limite_inferior(tour_parcial, custos, num_vertices)
            if limite_inferior < melhor_custo:
                for i in range(num_vertices):
                    if i not in tour_parcial:
                        novo_tour_parcial = tour_parcial + [i]
                        novo_custo_parcial = calcular_custo_tour(novo_tour_parcial, custos)
                        pilha.append((novo_tour_parcial, novo_custo_parcial))

    return melhor_tour, melhor_custo

# %%
def ler_entrada(caminho_arquivo):
    with open(caminho_arquivo, 'r') as file:
        lines = file.readlines()
        num_vertices = int(lines[0].strip())
        custos = {}

        for line in lines[1:]:
            i, j, k, custo = map(int, line.strip().split())
            custos[(i, j, k)] = custo

    return num_vertices, custos

def calcular_custo_tour(tour, custos):
    custo_total = 0
    n = len(tour)
    for i in range(n):
        custo_total += custos.get((tour[i], tour[(i+1) % n], tour[(i+2) % n]), float('inf'))
    return custo_total

def calcular_limite_inferior(tour_parcial, custos, num_vertices):
    # Esta função calcula um limite inferior para um tour parcial
    custo_total = calcular_custo_tour(tour_parcial, custos)
    vertices_restantes = set(range(num_vertices)) - set(tour_parcial)

    if not vertices_restantes:
        return custo_total

    # Adiciona um custo mínimo aproximado para as arestas faltantes
    custo_estimado = 0
    for i in vertices_restantes:
        menor_custo = min(custos.get((tour_parcial[-1], i, j), float('inf')) for j in vertices_restantes)
        custo_estimado += menor_custo

    return custo_total + custo_estimado

def branch_and_bound(num_vertices, custos):
    melhor_tour = None
    melhor_custo = float('inf')
    pilha = [([i], 0) for i in range(num_vertices)]

    while pilha:
        tour_parcial, custo_parcial = pilha.pop()

        if len(tour_parcial) == num_vertices:
            custo_total = calcular_custo_tour(tour_parcial, custos)
            if custo_total < melhor_custo:
                melhor_custo = custo_total
                melhor_tour = tour_parcial
        else:
            limite_inferior = calcular_limite_inferior(tour_parcial, custos, num_vertices)
            if limite_inferior < melhor_custo:
                for i in range(num_vertices):
                    if i not in tour_parcial:
                        novo_tour_parcial = tour_parcial + [i]
                        novo_custo_parcial = calcular_custo_tour(novo_tour_parcial, custos)
                        pilha.append((novo_tour_parcial, novo_custo_parcial))

    return melhor_tour, melhor_custo

# %%
# DEFININDO ARQUIVOS DE ENTRADA

NOMES_ARQUIVOS = ["FIS13-0.txt"]
CAMINHO_PASTA = "/content/drive/My Drive/EDA/Projeto"
CAMINHO_PASTA_ENTRADA = f"{CAMINHO_PASTA}/entrada"
CAMINHO_PASTA_SAIDA = f"{CAMINHO_PASTA}/saida"


def main():
    # Caminho para o arquivo de entrada
    caminho_arquivo_entrada = f"{CAMINHO_PASTA}/entrada/{NOMES_ARQUIVOS[0]}"

    # Caminho para o arquivo de saida
    caminho_arquivo_saida = f"{CAMINHO_PASTA}/saida/{NOMES_ARQUIVOS[0]}"

    # Lendo os dados de entrada
    num_vertices, custos = ler_entrada(caminho_arquivo_entrada)

    # Resolvendo o QTSP usando branch-and-bound
    inicio = time.time()
    melhor_tour, melhor_custo = branch_and_bound(num_vertices, custos)
    fim = time.time()

    # Imprimindo os resultados
    print(f'Melhor tour: {melhor_tour}')
    print(f'Melhor custo: {melhor_custo}')
    print(f'Tempo de execução: {fim - inicio} segundos')

    # Escrevendos os resultados em arquivos
    with open(caminho_arquivo_saida, 'w') as arquivo_saida:
        arquivo_saida.write(f'Melhor tour: {melhor_tour}\n')
        arquivo_saida.write(f'Melhor custo: {melhor_custo}\n')
        arquivo_saida.write(f'Tempo de execução: {fim - inicio} segundos\n')

if __name__ == "__main__":
    main()
# Out:
# Melhor tour: [10, 4, 12, 11, 7, 5, 6, 1, 9, 2, 8, 0, 3]
# Melhor custo: 21813
# Tempo de execução: 62.17163920402527 segundos

# %%
# !!!!!!! INTERANDO SOBRE TODOS OS ARQUIVOS DE ENTRADA
## Pode mudar a pasta ter apenas os arquivos que podem ser executados

CAMINHO_PASTA = "/content/drive/My Drive/EDA/Projeto"
CAMINHO_PASTA_ENTRADA = f"{CAMINHO_PASTA}/entrada"
CAMINHO_PASTA_SAIDA = f"{CAMINHO_PASTA}/saida"


def main():
    # Cria a pasta de saida se ela não existir
    os.makedirs(CAMINHO_PASTA_SAIDA, exist_ok=True)


    # Intera sobre os arquivso na pasta entrada
    for nome_arquivo in os.listdir(CAMINHO_PASTA_ENTRADA):
        caminho_arquivo_entrada = os.path.join(CAMINHO_PASTA_ENTRADA, nome_arquivo)
        caminho_arquivo_saida = os.path.join(CAMINHO_PASTA_SAIDA, f"resultados_porpasta_{nome_arquivo}")
        print(nome_arquivo)
        # Lendo os dados de entrada
        num_vertices, custos = ler_entrada(caminho_arquivo_entrada)

        # Resolvendo o QTSP usando branch-and-bound
        inicio = time.time()
        melhor_tour, melhor_custo = branch_and_bound(num_vertices, custos)
        fim = time.time()

        # Escrevendo os resultados em um arquivo de saída
        with open(caminho_arquivo_saida, 'w') as arquivo_saida:
            arquivo_saida.write(f'Melhor tour: {melhor_tour}\n')
            arquivo_saida.write(f'Melhor custo: {melhor_custo}\n')
            arquivo_saida.write(f'Tempo de execução: {fim - inicio} segundos\n')

if __name__ == "__main__":
    main()
# Out:
# FIS24-0.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-dcc2b3e130d5> in <cell line: 33>()
#      32
#      33 if __name__ == "__main__":
# ---> 34     main()
#
# <ipython-input-16-dcc2b3e130d5> in main()
#      22         # Resolvendo o QTSP usando branch-and-bound
#      23         inicio = time.time()
# ---> 24         melhor_tour, melhor_custo = branch_and_bound(num_vertices, custos)
#      25         fim = time.time()
#      26
#
# <ipython-input-10-3ae1c8cff7fd> in branch_and_bound(num_vertices, custos)
#      48                 melhor_tour = tour_parcial
#      49         else:
# ---> 50             limite_inferior = calcular_limite_inferior(tour_parcial, custos, num_vertices)
#      51             if limite_inferior < melhor_custo:
#      52                 for i in range(num_vertices):
#
# <ipython-input-10-3ae1c8cff7fd> in calcular_limite_inferior(tour_parcial, custos, num_vertices)
#      29     custo_estimado = 0
#      30     for i in vertices_restantes:
# ---> 31         menor_custo = min(custos.get((tour_parcial[-1], i, j), float('inf')) for j in vertices_restantes)
#      32         custo_estimado += menor_custo
#      33
#
# <ipython-input-10-3ae1c8cff7fd> in <genexpr>(.0)
#      29     custo_estimado = 0
#      30     for i in vertices_restantes:
# ---> 31         menor_custo = min(custos.get((tour_parcial[-1], i, j), float('inf')) for j in vertices_restantes)
#      32         custo_estimado += menor_custo
#      33
#
# KeyboardInterrupt:
